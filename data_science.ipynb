# %% [markdown]
# <a href="https://colab.research.google.com/github/Kevin-Nguyen-24/AI/blob/main/data_science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Ingest**

# %% [markdown]
# # **EDA**

# %% [markdown]
# # **Modeling**

# %% [markdown]
# # **Conclusion**
